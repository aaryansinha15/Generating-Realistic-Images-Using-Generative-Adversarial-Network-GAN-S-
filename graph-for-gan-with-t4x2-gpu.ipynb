# %%
import matplotlib.pyplot as plt

# Example arrays (replace these with your actual arrays)
losses_g = [[5.0803],
            [6.3482],
            [10.0505],
            [4.6057],
            [6.5036],
            [4.4181],
            [3.1502],
            [6.2669],
            [6.2782],
            [5.9005],
            [16.2838],
            [4.3134],
            [8.0123]]  # List of arrays for generator losses for different runs
losses_d = [[0.8331],
            [0.6083],
            [0.4252],
            [0.0604],
            [0.0796],
            [0.2255],
            [0.3355],
            [0.0677],
            [0.0767],
            [0.2343],
            [3.1203],
            [0.0338],
            [0.0529]]  # List of arrays for discriminator losses for different runs
real_scores = [[0.9671],
            [0.6304],
            [0.9818],
            [0.9503],
            [0.9772],
            [0.8760],
            [0.8055],
            [0.9403],
            [0.9857],
            [0.8274],
            [1.0000],
            [0.9844],
            [0.9531]]  # List of arrays for real discriminator scores for different runs
fake_scores = [[0.5049],
            [0.0046],
            [0.2946],
            [0.0064],
            [0.0462],
            [0.0457],
            [0.0488],
            [0.0032],
            [0.0525],
            [0.0089],
            [0.8008],
            [0.0169],
            [0.0006]]  # List of arrays for fake discriminator scores for different runs

# Plotting generator and discriminator loss
plt.figure(figsize=(10, 5))
plt.plot(losses_g, label='Generator Loss')
plt.plot(losses_d, label='Discriminator Loss')
plt.title('Training Losses')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
plt.savefig('/kaggle/working/Training_loss_Graph.png')

# Plotting discriminator scores
plt.figure(figsize=(10, 5))
plt.plot(real_scores, label='Real Score')
plt.plot(fake_scores, label='Fake Score')
plt.title('Discriminator Scores')
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.legend()
plt.show()
plt.savefig('/kaggle/working/Discriminator_Score_REAL_FAKE_Graph.png')
